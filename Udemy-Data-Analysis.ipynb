# %% [markdown]
# **Udemy is looking to provide more value to her customers by offering her more affordable and quality courses. They’ve provided a dataset for their musical courses for you to help them achieve this.**
#
# **Craft a problem Statement**
# **Frame the problem with respect to how your expertise can help them solve the problem.**
# Write down steps you would take to arrive at your solutions.
#
# Hint: Use a markdown cell to answer questions 1 to 3

# %% [markdown]
# **`Problem Statement`**
#
# *Udemy is looking to improve its value to her customers by offering more affordable and high-quality musical courses. However, the challenge lies in identifying the most effective strategies to imbibe to execute their expectations while ensuring the meet various needs and expectations of learners while maintaining profitability and customer satisfaction.*
#
# *Two possible options to achieve this has been highlighted*:
#
# * *Making the courses affordable*
#
# * *Improving the quality of the course*

# %% [markdown]
# **`Expertise Approach`**
#
# *As an expert in data analysis, course optimization, I can leverage the provided dataset to identify patterns, trends, and insights that will enable Udemy to tailor their musical course offerings more effectively. By understanding the demographics, interests, and learning behaviors of their target audience, Udemy can strategically develop and promote courses that are both affordable and of high quality*.
#
# *we would need a dataset that has the following attributes*:
#
# `Price of courses`
#
# `Course rating`
#
# `No of Reviews`
#
# `other interesting attributes we can explore`

# %% [markdown]
# **`Solution steps`**:
#
# * Define Customer Satisfaction
#
# * Explore the data and prepare it
#
# * Answer a couple questions about the data vis a vis the problem.
#
# * Summarize our findings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('Data_Sheet_Udemy_Courses_Music_Courses.csv')

# %%
df
# Out:
#      course_id                                       course_title  \
# 0        19421              Free Beginner Electric Guitar Lessons
# 1       238934  Pianoforall - Incredible New Way To Learn Pian...
# 2        41884                Getting Started with Playing Guitar
# 3        42271      Complete Guitar System - Beginner to Advanced
# 4        26956                            Learn Guitar in 21 Days
# ..         ...                                                ...
# 675    1216340                  Learn to Play Sweet Child of Mine
# 676    1026762  Coaching Course: Rhythm Instruction for Music ...
# 677    1223240  Learn Pirates of the Caribbean by Ear on the P...
# 678    1224186  Learn to Play Piano Like a Pro - Easy Piano Co...
# 679    1234656                              4 Week Rhythm Mastery
#
#                                                    url  price  \
# 0    https://www.udemy.com/beginner-electric-guitar...      0
# ...

# %% [markdown]
# **Data Exploration/Profiling**

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0      19421              Free Beginner Electric Guitar Lessons
# 1     238934  Pianoforall - Incredible New Way To Learn Pian...
# 2      41884                Getting Started with Playing Guitar
# 3      42271      Complete Guitar System - Beginner to Advanced
# 4      26956                            Learn Guitar in 21 Days
#
#                                                  url  price  num_subscribers  \
# 0  https://www.udemy.com/beginner-electric-guitar...      0           101154
# 1  https://www.udemy.com/pianoforall-incredible-n...    200            75499
# 2  https://www.udemy.com/getting-started-with-pla...      0            47652
# 3  https://www.udemy.com/complete-guitar-system-b...    145            32935
# 4     https://www.udemy.com/learn-guitar-in-21-days/     20            26504
#
#    num_reviews  num_lectures           level  Rating  content_duration  \
# ...

# %%
df.shape
# Out:
# (680, 12)

# %% [markdown]
# **680 rows is not so much data but we can start from there**

# %%
## get all the columns and have a deeper understanding of what each represents

columns = [i for i in df.columns]

# %%
columns
# Out:
# ['course_id',
#  'course_title',
#  'url',
#  'price',
#  'num_subscribers',
#  'num_reviews',
#  'num_lectures',
#  'level',
#  'Rating',
#  'content_duration',
#  'published_timestamp',
#  'subject']

# %% [markdown]
#  **`Data dictionary`**:
#
# `Course_id`:A unique identifier for each course in the dataset
#
# `course_title`:The title or name of the course
#
# `url`:The URL or link to the course.
#
# `price`:The price of the course.(Data Type: Numeric (float or integer))
#
# `num_subscribers`:The number of subscribers enrolled in the course.(Data Type: Numeric (integer))
#
# `num_reviews`: The number of reviews the course has received.(Data Type: Numeric (integer))
#
# `num_lecture`:The number of lectures or lessons in the course.
#
# `level`: The difficulty level of the course.
#
# `Rating`:The overall rating of the course.
#
# `content_duration`:The total duration of the course content.
#
# `published_timestamp`:The timestamp when the course was published or made available.
#
# `subject`:The subject or topic of the course.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            680 non-null    int64
#  1   course_title         680 non-null    object
#  2   url                  680 non-null    object
#  3   price                680 non-null    int64
#  4   num_subscribers      680 non-null    int64
#  5   num_reviews          680 non-null    int64
#  6   num_lectures         680 non-null    int64
#  7   level                680 non-null    object
#  8   Rating               680 non-null    float64
#  9   content_duration     680 non-null    float64
#  10  published_timestamp  680 non-null    object
#  11  subject              680 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 63.9+ KB

# %% [markdown]
# * There are no null values but price should be a float and let's assume its unit is dollars.
#
#
# * content duration has no units(should be hrs, min etc)
#
#
# * published timestamp should be in datetime
#
#
# * we don't need the course id

# %%
df.describe()
# Out:
#           course_id       price  num_subscribers  num_reviews  num_lectures  \
# count  6.800000e+02  680.000000       680.000000   680.000000    680.000000
# mean   6.386484e+05   49.558824      1245.130882    46.652941     38.316176
# std    3.472305e+05   41.187592      5676.381419   337.735677     42.739700
# min    1.221400e+04    0.000000         0.000000     0.000000      4.000000
# 25%    3.383060e+05   20.000000        31.000000     2.000000     14.000000
# 50%    6.533970e+05   40.000000       138.000000     5.000000     25.000000
# 75%    9.172400e+05   50.000000       870.250000    17.000000     43.000000
# max    1.272282e+06  200.000000    101154.000000  7676.000000    362.000000
#
#            Rating  content_duration
# count  680.000000        680.000000
# mean     0.308912          2.854387
# std      0.303799          3.470463
# min      0.000000          0.483333
# 25%      0.070000          1.000000
# 50%      0.150000          2.000000
# ...

# %% [markdown]
# **Interesting Stats**
#
# **`Price`**
#
#
# * Average Price of a course is apprx 50 dollars (not so high)
#
#
# * The most expensive course cost 200 dollars
#
#
# * The least expensive course is 0 dollars indicating that they offer free courses
#
#
# * The standard deviation is apprx 41 dollars indicating that there are some courses that are way more expensive than the average and some way less expensive
#
#
#
# **`Rating`**
#
# * Average rating is 0.30 (quite poor)
#
#
# * Std is 0.3 indicating some courses did averagely well while some didn't
#
#
# * Max is 1, min is 0. Notice that the free courses are the ones rated 0.

# %%
cat = df.select_dtypes(include=['category', 'object'])
cat_columns = [i for i in cat.columns]

# %%
cat_columns
# Out:
# ['course_title', 'url', 'level', 'published_timestamp', 'subject']

# %%
for i in cat_columns:
    print('-------------------------------')
    print('-------------------------------')
    print(df[i].value_counts())
# Out:
# -------------------------------
# -------------------------------
# course_title
# Acoustic Blues Guitar Lessons                                   3
# Aprende a tocar el acordeón de botones                          2
# Drum Lessons For Beginners                                      2
# Piano With Willie: Jazz & Gospel Exercises                      1
# Blues Guitar Lessons: Play Like the Greats - All Levels         1
#                                                                ..
# Play Piano 7: Improvise on For All We Know in F Key by Ear      1
# Play Autumn Leaves' falling notes on piano with no reading!     1
# Instant Harmonica - play Somewhere Over the Rainbow now!        1
# Learn to Play Percussion: Beginner to Pro made the Easy Way!    1
# 4 Week Rhythm Mastery                                           1
# Name: count, Length: 676, dtype: int64
# -------------------------------
# -------------------------------
# url
# ...

# %% [markdown]
# **Interesting Findings**
#
# * There are more beginner level courses compared to intermediate and then expert level courses
#
#
# * Some course titles are repeated

# %% [markdown]
# # **Data Cleaning**

# %%
# check for null values

df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# Rating                 0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
# check for duplicates

df.duplicated().sum()
# Out:
# 0

# %%
# rename the price and content duration column to include the units

df.rename(columns={'price': 'price ($)'}, inplace=True)

# %%
df.rename(columns={'content_duration' : 'content_duration (hrs)'}, inplace=True)

# %%
# confirm changes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   course_id               680 non-null    int64
#  1   course_title            680 non-null    object
#  2   url                     680 non-null    object
#  3   price ($)               680 non-null    int64
#  4   num_subscribers         680 non-null    int64
#  5   num_reviews             680 non-null    int64
#  6   num_lectures            680 non-null    int64
#  7   level                   680 non-null    object
#  8   Rating                  680 non-null    float64
#  9   content_duration (hrs)  680 non-null    float64
#  10  published_timestamp     680 non-null    object
#  11  subject                 680 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 63.9+ KB

# %%
# drop the course_id as we don't need it for analysis

df.drop('course_id', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   course_title            680 non-null    object
#  1   url                     680 non-null    object
#  2   price ($)               680 non-null    int64
#  3   num_subscribers         680 non-null    int64
#  4   num_reviews             680 non-null    int64
#  5   num_lectures            680 non-null    int64
#  6   level                   680 non-null    object
#  7   Rating                  680 non-null    float64
#  8   content_duration (hrs)  680 non-null    float64
#  9   published_timestamp     680 non-null    object
#  10  subject                 680 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 58.6+ KB

# %%
# convert price to float and timestamp to datetime

df['price ($)'] = df['price ($)'].astype('float64')

# %%
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])

# %%
# confirm changes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   course_title            680 non-null    object
#  1   url                     680 non-null    object
#  2   price ($)               680 non-null    float64
#  3   num_subscribers         680 non-null    int64
#  4   num_reviews             680 non-null    int64
#  5   num_lectures            680 non-null    int64
#  6   level                   680 non-null    object
#  7   Rating                  680 non-null    float64
#  8   content_duration (hrs)  680 non-null    float64
#  9   published_timestamp     680 non-null    datetime64[ns, UTC]
#  10  subject                 680 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(3), object(4)
# memory usage: 58.6+ KB

# %%
df.head()
# Out:
#                                         course_title  \
# 0              Free Beginner Electric Guitar Lessons
# 1  Pianoforall - Incredible New Way To Learn Pian...
# 2                Getting Started with Playing Guitar
# 3      Complete Guitar System - Beginner to Advanced
# 4                            Learn Guitar in 21 Days
#
#                                                  url  price ($)  \
# 0  https://www.udemy.com/beginner-electric-guitar...        0.0
# 1  https://www.udemy.com/pianoforall-incredible-n...      200.0
# 2  https://www.udemy.com/getting-started-with-pla...        0.0
# 3  https://www.udemy.com/complete-guitar-system-b...      145.0
# 4     https://www.udemy.com/learn-guitar-in-21-days/       20.0
#
#    num_subscribers  num_reviews  num_lectures           level  Rating  \
# 0           101154         1042            95      All Levels    0.88
# 1            75499         7676           362  Beginner Level    0.96
# ...

# %%
# export cleaned data

df.to_csv('cleaned_udemy_music_courses_data.csv')

# %% [markdown]
# # **Exploration via visualization**

# %%
# generate the countplot for each categorical column

cat_columns
# Out:
# ['course_title', 'url', 'level', 'published_timestamp', 'subject']

# %%
plt.figure(figsize=(20, 8))

sb.countplot(y='level', data=df)
plt.title('Countplot of Level')
# Out:
# Text(0.5, 1.0, 'Countplot of Level')

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

sb.countplot(y='subject', data=df)
plt.title('Countplot of Subject')
# Out:
# Text(0.5, 1.0, 'Countplot of Subject')

# %%
sb.countplot(x='course_title', data=df)
plt.title('Countplot of course_title')
# Out:
# Text(0.5, 1.0, 'Countplot of course_title')

# %%
# Histogram Plot of numerical columns

num = df.select_dtypes(include=['int64', 'float64'])
num_columns = [i for i in num.columns]

# %%
num_columns
# Out:
# ['price ($)',
#  'num_subscribers',
#  'num_reviews',
#  'num_lectures',
#  'Rating',
#  'content_duration (hrs)']

# %%
for column in num_columns:
    plt.hist(df[column], bins=10, color='skyblue', edgecolor='black', alpha=0.7) 
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Box plot of Numerical Columns

for column in num_columns:
    plt.figure(figsize=(20,8))
    plt.boxplot(df[column], notch=True, patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'), medianprops=dict(color='red', linewidth=2), whiskerprops=dict(color='green', linewidth=1.5, linestyle='--'), capprops=dict(color='purple', linewidth=1.5), flierprops=dict(marker='o', markersize=8, markerfacecolor='yellow', markeredgecolor='black'), vert=False)
    plt.title(f'Box plot of {column}')
    plt.ylabel(column)
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.tight_layout() 
    plt.show()

# %%
# do a seperate box plot for num_review and num_subscribers so we can see the box clearly
plt.boxplot(df['num_reviews'], notch=True, patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'), medianprops=dict(color='red', linewidth=2), whiskerprops=dict(color='green', linewidth=1.5, linestyle='--'), capprops=dict(color='purple', linewidth=1.5), flierprops=dict(marker='o', markersize=8, markerfacecolor='yellow', markeredgecolor='black'), vert=False)
plt.xlim(0,150)
plt.ylabel('Num of Reviews')
plt.show()

# %%
plt.boxplot(df['num_subscribers'], notch=True, patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'), medianprops=dict(color='red', linewidth=2), whiskerprops=dict(color='green', linewidth=1.5, linestyle='--'), capprops=dict(color='purple', linewidth=1.5), flierprops=dict(marker='o', markersize=8, markerfacecolor='yellow', markeredgecolor='black'), vert=False)
plt.xlim(0,5000)
plt.ylabel('Num of Subscrivers')
plt.show()

# %% [markdown]
# **Data Analysis**

# %% [markdown]
# `1` Total number of subscribers, total no of reviews, total no of lectures, average rating, average content duration, average price

# %%
for col in num_columns:
    print(f'Stats for {col}')
    print(f'Total : {df[col].sum()}')
    print(f' Average : {df[col].mean()}')
    print('-------------------------')
# Out:
# Stats for price ($)
# Total : 33700.0
#  Average : 49.55882352941177
# -------------------------
# Stats for num_subscribers
# Total : 846689
#  Average : 1245.1308823529412
# -------------------------
# Stats for num_reviews
# Total : 31724
#  Average : 46.65294117647059
# -------------------------
# Stats for num_lectures
# Total : 26055
#  Average : 38.31617647058823
# -------------------------
# Stats for Rating
# Total : 210.06
#  Average : 0.30891176470588233
# -------------------------
# Stats for content_duration (hrs)
# Total : 1940.9833333331999
#  Average : 2.8543872549017646
# -------------------------

# %% [markdown]
# `2`. Distribution of course price

# %%
plt.hist(df['price ($)'], bins=10, color='skyblue', edgecolor='black', alpha=0.7) 
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
sb.kdeplot(df['price ($)'], color='blue', linewidth=2, linestyle='--', shade=True)
plt.show()

# %% [markdown]
# `3`. Comparison between rating/price/subscribers vs course level

# %%
df_price_by_courseLevel = df.groupby(by='level')[['price ($)']].mean()

# %%
# sort the results 
df_price_by_courseLevel = df_price_by_courseLevel.sort_values(by='price ($)', ascending=False)
df_price_by_courseLevel
# Out:
#                     price ($)
# level
# Intermediate Level  51.602564
# All Levels          49.583333
# Beginner Level      48.984962
# Expert Level        48.333333

# %%
plt.bar(df_price_by_courseLevel.index, df_price_by_courseLevel['price ($)'], color='skyblue', edgecolor='black', linewidth=1)
plt.title('Average Price of courses for different course levels')
plt.xlabel('Level')
plt.ylabel('Average Price')
plt.show()

# %%
df_rating_by_courseLevel = df.groupby(by='level')[['Rating']].mean()

# %%
df_rating_by_courseLevel = df_rating_by_courseLevel.sort_values(by='Rating', ascending=False)
df_rating_by_courseLevel
# Out:
#                       Rating
# level
# Beginner Level      0.313835
# All Levels          0.312037
# Expert Level        0.296667
# Intermediate Level  0.281026

# %%
plt.bar(df_rating_by_courseLevel.index, df_rating_by_courseLevel['Rating'], color='grey', edgecolor='black', linewidth=1)
plt.title('Average Rating of courses for different course levels')
plt.xlabel('Level')
plt.ylabel('Average Rating')
plt.show()

# %%
df_subscribers_by_courseLevel = df.groupby(by='level')[['num_subscribers']].sum()

# %%
df_subscribers_by_courseLevel = df_subscribers_by_courseLevel.sort_values(by='num_subscribers', ascending=False)
df_subscribers_by_courseLevel
# Out:
#                     num_subscribers
# level
# All Levels                   465044
# Beginner Level               285531
# Intermediate Level            79722
# Expert Level                  16392

# %%
plt.figure(figsize=(20,8))
plt.bar(df_subscribers_by_courseLevel.index, df_subscribers_by_courseLevel['num_subscribers'], color='tan', edgecolor='black', linewidth=1)
plt.title('Total numbers of Subscribers for different course levels')
plt.xlabel('Level')
plt.ylabel('Total Subscribers')
plt.show()

# %% [markdown]
# `4` Course with the best rating and course with the worst rating

# %%
# get the best rating and worst rating

df['Rating'].max()
# Out:
# 1.0

# %%
df['Rating'].min()
# Out:
# 0.0

# %%
#course or courses with a rating of 1.0
df[df['Rating'] == 1.0]
# Out:
#                                           course_title  \
# 159  #5  Piano Hand Coordination:  Piano Runs in 2 ...
# 332         Learn How To Play 25 Classic Hip Hop Songs
# 379  Learn 3 - All Time A R Rahman Hits on Carnatic...
# 642                      Aprende a tocar el clarinete.
#
#                                                    url  price ($)  \
# 159  https://www.udemy.com/learn-piano-technique-5-...       75.0
# 332  https://www.udemy.com/learn-how-to-play-25-cla...       25.0
# 379               https://www.udemy.com/arrahman-hits/       70.0
# 642  https://www.udemy.com/aprende-a-tocar-el-clari...       50.0
#
#      num_subscribers  num_reviews  num_lectures       level  Rating  \
# 159              940            3            32  All Levels     1.0
# 332              153            9            27  All Levels     1.0
# 379               98           18            31  All Levels     1.0
# 642                4            0            26  All Levels     1.0
#
# ...

# %%
df[df['Rating'] == 0.0]
# Out:
#                                           course_title  \
# 609  Poldark TV series Soundtracks for Piano-Quickl...
# 610  The Art of the Blues Shuffle - A Guitarist's G...
# 611     Beginner Level Popular Piano Program - Month 1
# 612                        Guitarra para principiantes
# 613       Aprende a tocar ritmos latinos en el teclado
# 614  Aprende todos los secretos de la salsa para piano
# 615    Blues Master - Advanced Techniques Piano Course
# 616                        Aprende a tocar la guitarra
# 617    Learn How To Play 25 Classic Hip Hop Songs Ch.2
# 618       Learn Piano Online-A Quiet Solace Piano Solo
# 619                              Guitar for Christmas!
#
#                                                    url  price ($)  \
# 609  https://www.udemy.com/poldark-tv-series-soundt...       20.0
# 610  https://www.udemy.com/the-art-of-the-blues-shu...       20.0
# 611  https://www.udemy.com/beginner-level-popular-p...       30.0
# ...

# %% [markdown]
# `5` How total no of courses published have changed over the years

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   course_title            680 non-null    object
#  1   url                     680 non-null    object
#  2   price ($)               680 non-null    float64
#  3   num_subscribers         680 non-null    int64
#  4   num_reviews             680 non-null    int64
#  5   num_lectures            680 non-null    int64
#  6   level                   680 non-null    object
#  7   Rating                  680 non-null    float64
#  8   content_duration (hrs)  680 non-null    float64
#  9   published_timestamp     680 non-null    datetime64[ns, UTC]
#  10  subject                 680 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(3), object(4)
# memory usage: 58.6+ KB

# %%
# extract year from timeStamp column and create a new column called year published

df['Year Published'] = df['published_timestamp'].dt.year

# %%
df.head()
# Out:
#                                         course_title  \
# 0              Free Beginner Electric Guitar Lessons
# 1  Pianoforall - Incredible New Way To Learn Pian...
# 2                Getting Started with Playing Guitar
# 3      Complete Guitar System - Beginner to Advanced
# 4                            Learn Guitar in 21 Days
#
#                                                  url  price ($)  \
# 0  https://www.udemy.com/beginner-electric-guitar...        0.0
# 1  https://www.udemy.com/pianoforall-incredible-n...      200.0
# 2  https://www.udemy.com/getting-started-with-pla...        0.0
# 3  https://www.udemy.com/complete-guitar-system-b...      145.0
# 4     https://www.udemy.com/learn-guitar-in-21-days/       20.0
#
#    num_subscribers  num_reviews  num_lectures           level  Rating  \
# 0           101154         1042            95      All Levels    0.88
# 1            75499         7676           362  Beginner Level    0.96
# ...

# %%
df_courses_published_perYear = df.groupby(by='Year Published')[['url']].count()

# %%
df_courses_published_perYear
# Out:
#                 url
# Year Published
# 2012             10
# 2013             39
# 2014            120
# 2015            171
# 2016            228
# 2017            112

# %%
plt.figure(figsize=(20,8))
plt.plot(df_courses_published_perYear.index, df_courses_published_perYear['url'], color='tan', linewidth=2, marker='o', markersize=8, linestyle='--')
plt.title('Trend of courses published per year')
plt.xlabel('Year')
plt.ylabel('Total Number of courses published')
plt.show()

# %% [markdown]
# # **Summary of Findings**
#
# * The number of courses published steadily grew from 2012 to 2016, there was a decline from 2016 to 2017
